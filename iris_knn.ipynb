# %% [markdown]
# <a href="https://colab.research.google.com/github/sreerag6224/datascience/blob/main/iris_knn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
iris= load_iris()

# %%
X=iris.data
Y=iris.target

print(X)
print()
print(Y)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (150, 4)
# (150,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score

knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X,Y)
y_pred=knn.predict(X)
print(metrics.accuracy_score(Y,y_pred))
# Out:
# 0.9666666666666667

# %%
from sklearn.model_selection import  train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.4,random_state=4)
print(X_train.shape)
print(Y_train.shape)
print()
print(Y_test.shape)
print(Y_test.shape)
# Out:
# (90, 4)
# (90,)
#
# (60,)
# (60,)

# %%
knn=KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train,Y_train)
y_pred=knn.predict(X_test)
print(metrics.accuracy_score(Y_test,y_pred))
# Out:
# 0.9833333333333333

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
logreg.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logreg.predict(X_test)
print(metrics.accuracy_score(Y_test,y_pred))
# Out:
# 0.9666666666666667

# %%
knn=KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,Y_train)
y_pred=knn.predict(X_test)
print(metrics.accuracy_score(Y_test,y_pred))
# Out:
# 0.95

# %%
k_range=list(range(1,26))
scores=[]
for k in k_range:
  knn=KNeighborsClassifier(n_neighbors=k)
  knn.fit(X_train,Y_train)
  y_pred=knn.predict(X_test)
  scores.append(metrics.accuracy_score(Y_test,y_pred))
  print(metrics.accuracy_score(Y_test,y_pred))
# Out:
# 0.95
# 0.95
# 0.9666666666666667
# 0.9666666666666667
# 0.9666666666666667
# 0.9833333333333333
# 0.9833333333333333
# 0.9833333333333333
# 0.9833333333333333
# 0.9833333333333333
# 0.9833333333333333
# 0.9833333333333333
# 0.9833333333333333
# 0.9833333333333333
# 0.9833333333333333
# 0.9833333333333333
# 0.9833333333333333
# 0.9666666666666667
# 0.9833333333333333
# 0.9666666666666667
# 0.9666666666666667
# 0.9666666666666667
# 0.9666666666666667
# 0.95
# 0.95

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(k_range,scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
# Out:
# Text(0, 0.5, 'Testing Accuracy')

# %%
knn = KNeighborsClassifier(n_neighbors=11)
knn.fit(X_train, Y_train)
knn.predict([[3, 5, 4, 2],[5,6,3,6]])
# Out:
# array([1, 2])
